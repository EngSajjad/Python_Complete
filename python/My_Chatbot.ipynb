# %%
from nltk.chat.util import Chat, reflections

#Pairs is a list of patterns and responses.
pairs = [
    [
        r"(.*)my name is (.*)",
        ["Hello %2, How are you today ?",]
    ],
    [
        r"(.*)help(.*) ",
        ["I can help you ",]
    ],
    [
        r"(.*) your name ?",
        ["My name is chatbot, but you can just call me robot .",]
    ],
    [
        r"(.*)how are you(.*) ?",
        ["I'm doing very well", "i am great !"]
    ],
    [
        r"sorry (.*)",
        ["Its alright","Its OK, never mind that",]
    ],
    [
        r"i'm (.*) (good|well|okay|ok)",
        ["Nice to hear that","Alright, great !",]
    ],
    [
        r"(hi|hey|hello|hola|holla)(.*)",
        ["Hello", "Hey there",]
    ],
    [
        r"what (.*) want ?",
        ["Make me an offer I can't refuse",]
        
    ],
    [
        r"(.*)(created|creator)(.*)",
        ["Sajjad Bukhari created me using Python's NLTK library ",]
    ],
    [
        r"(.*) (location|city) ?",
        ['BahawalPur, Pakistan',]
    ],
    [
        r"(.*)raining in (.*)",
        ["No rain in the past 4 days here in %2","In %2 there is a 50% chance of rain",]
    ],
    [
        r"(.*) health (.*)",
        ["Health is very important, but I am a computer, so I don't need to worry about my health ",]
    ],
    [
        r"(.*)(sports|game|sport)(.*)",
        ["I'm a very big fan of Cricket",]
    ],
    [
        r"who (.*)Batsman?(.*)",
        ["Shahid Afridi"]
    ],
    [
        r"quit",
        ["Bye for now. See you soon :) ","It was nice talking to you. See you soon :)"]
    ],
    [
        r"(.*)",
        ['That is nice to hear']
    ],
   
]

#default message at the start of chat
print("Hi, I'm Chatbot. created By Sajjad and I like to chat\nPlease type lowercase English language to start a conversation. Type quit to leave ")
#Create Chat Bot
chat = Chat(pairs, reflections)
#Start conversation
chat.converse()
# Out:
# Hi, I'm Chatbot. created By Sajjad and I like to chat
# Please type lowercase English language to start a conversation. Type quit to leave
# >who are you
# That is nice to hear
# >how are you
# i am great !
# >who is your creater
# That is nice to hear
# >who is creator you
# Sajjad Bukhari created me using Python's NLTK library
# >how are you
# i am great !
# >who is your creator
# Sajjad Bukhari created me using Python's NLTK library
# >are you help me
# I can help you
# >quit
# It was nice talking to you. See you soon :)
